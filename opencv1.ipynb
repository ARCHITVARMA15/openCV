# %%
import cv2
import numpy as np

# %%
img = cv2.imread("images/dog1.jpg")

# %%
print(type(img))
# Out:
# <class 'numpy.ndarray'>

# %%
cv2.imshow("Dog", img)
cv2.waitKey(10)
cv2.destroyAllWindows()
