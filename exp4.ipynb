# %%
import cv2

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv2.imread('images/dog1.jpg')
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb)
plt.axis("off")
plt.show()

# %%
high_pass_kernel = np.array([
    [-1, -1, -1],
    [-1,  8, -1],
    [-1, -1, -1]
])

# %%
# Convert image to uint8
image_uint8 = np.array(image, dtype=np.uint8)

# Convert kernel to float32
high_pass_kernel = np.array([
    [-1, -1, -1],
    [-1,  8, -1],
    [-1, -1, -1]
], dtype=np.float32)

# Apply High Pass Filter
high_pass = cv2.filter2D(
    image_uint8,
    ddepth=cv2.CV_32F,
    kernel=high_pass_kernel
)

print("Filtering completed successfully!")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 # Convert image to uint8
# ----> 2 image_uint8 = np.array(image, dtype=np.uint8)
#       3
#       4 # Convert kernel to float32
#       5 high_pass_kernel = np.array([
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'NoneType'
